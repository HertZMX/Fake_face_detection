# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd

image_data = pd.read_csv('/content/drive/MyDrive/2023_Spring/Advanced_Topics_in_DS/Project/small_processed_data/image_data.csv')
resnet = pd.read_csv('/content/drive/MyDrive/2023_Spring/Advanced_Topics_in_DS/Project/small_processed_data/resnet.csv')
densenet = pd.read_csv('/content/drive/MyDrive/2023_Spring/Advanced_Topics_in_DS/Project/small_processed_data/densenet.csv')
xception = pd.read_csv('/content/drive/MyDrive/2023_Spring/Advanced_Topics_in_DS/Project/small_processed_data/xception.csv')
shallownet = pd.read_csv('/content/drive/MyDrive/2023_Spring/Advanced_Topics_in_DS/Project/small_processed_data/shallownet.csv')

# %%
original_data = image_data[image_data['folder'] == 'test']

# %%
s = pd.Series(range(0,720))
original_data.set_index(s, inplace=True)

original_data
# Out:
#        id label dataset_name folder
# 0       0  real         ffhq   test
# 1       2  real         ffhq   test
# 2       3  real         ffhq   test
# 3       8  real         ffhq   test
# 4      25  real         ffhq   test
# ..    ...   ...          ...    ...
# 715  3115  fake    photoshop   test
# 716  3116  fake    photoshop   test
# 717  3117  fake    photoshop   test
# 718  3118  fake    photoshop   test
# 719  3119  fake    photoshop   test
#
# [720 rows x 4 columns]

# %%
image_data[image_data['folder']=='train'].label.value_counts()
# Out:
# real    1200
# fake    1200
# Name: label, dtype: int64

# %%
resnet.rename(columns={"original_data": "resnet_original", "high-pass_filter": "resnet_high_pass_filter", "to_hsv": "resnet_to_hsv"}, inplace=True)
resnet
# Out:
#      resnet_original  resnet_high_pass_filter  resnet_to_hsv
# 0                  0                        0              0
# 1                  1                        0              1
# 2                  0                        1              0
# 3                  1                        1              1
# 4                  0                        0              1
# ..               ...                      ...            ...
# 715                1                        1              1
# 716                0                        0              1
# 717                1                        0              1
# 718                1                        1              0
# 719                1                        0              1
#
# [720 rows x 3 columns]

# %%
densenet.rename(columns={"original_data": "densenet_original", "high-pass_filter": "densenet_high_pass_filter", "to_hsv": "densenet_to_hsv"}, inplace=True)
densenet
# Out:
#       densenet_original  densenet_50  densenet_highPass_50  densenet_hsv_50
# 0                     0            0                     0                0
# 1                     1            1                     0                1
# 2                     0            1                     0                1
# 3                     1            1                     1                1
# 4                     0            0                     0                1
# ...                 ...          ...                   ...              ...
# 1435                  0            1                     0                1
# 1436                  0            1                     0                1
# 1437                  0            1                     1                1
# 1438                  0            0                     1                0
# 1439                  1            1                     1                1
#
# [1440 rows x 4 columns]

# %%
densenet[0:720].head(20)
# Out:
#     densenet_original  densenet_50  densenet_highPass_50  densenet_hsv_50
# 0                   0            0                     0                0
# 1                   1            1                     0                1
# 2                   0            1                     0                1
# 3                   1            1                     1                1
# 4                   0            0                     0                1
# 5                   1            0                     0                1
# 6                   0            1                     1                1
# 7                   0            0                     1                0
# 8                   0            1                     0                1
# 9                   1            1                     1                0
# 10                  1            1                     0                1
# 11                  1            1                     0                1
# ...

# %%
densenet[720:].head(20)
# Out:
#      densenet_original  densenet_50  densenet_highPass_50  densenet_hsv_50
# 720                  0            0                     0                0
# 721                  1            1                     0                1
# 722                  0            1                     0                1
# 723                  1            1                     1                1
# 724                  0            0                     0                1
# 725                  1            0                     0                1
# 726                  0            1                     1                1
# 727                  0            0                     1                0
# 728                  0            1                     0                1
# 729                  1            1                     1                0
# 730                  1            1                     0                1
# ...

# %%
shallownet.rename(columns={"original_data": "shallownet_original", "high-pass_filter": "shallownet_high_pass_filter", "to_hsv": "shallownet_to_hsv"}, inplace=True)
shallownet
# Out:
#      shallownet_original  high_pass_filter  shallownet_to_hsv
# 0                      1                 1                  0
# 1                      1                 0                  1
# 2                      1                 1                  0
# 3                      0                 1                  1
# 4                      0                 0                  0
# ..                   ...               ...                ...
# 715                    1                 1                  0
# 716                    1                 1                  1
# 717                    1                 1                  1
# 718                    0                 0                  0
# 719                    1                 1                  0
#
# [720 rows x 3 columns]

# %%
xception.rename(columns={"original_data": "xception_original", "high-pass_filter": "xception_high_pass_filter", "to_hsv": "xception_to_hsv"}, inplace=True)
xception
# Out:
#      xception_original  high_pass_filter  xception_to_hsv
# 0                    0                 0                0
# 1                    1                 1                1
# 2                    1                 0                0
# 3                    1                 1                1
# 4                    0                 0                1
# ..                 ...               ...              ...
# 715                  1                 1                0
# 716                  0                 0                0
# 717                  1                 1                0
# 718                  0                 1                1
# 719                  1                 0                1
#
# [720 rows x 3 columns]

# %%
test_predictions = pd.concat([original_data, resnet], axis=1)
test_predictions
# Out:
#        id label dataset_name folder  resnet_original  resnet_high_pass_filter  \
# 0       0  real         ffhq   test                0                        0
# 1       2  real         ffhq   test                1                        0
# 2       3  real         ffhq   test                0                        1
# 3       8  real         ffhq   test                1                        1
# 4      25  real         ffhq   test                0                        0
# ..    ...   ...          ...    ...              ...                      ...
# 715  3115  fake    photoshop   test                1                        1
# 716  3116  fake    photoshop   test                0                        0
# 717  3117  fake    photoshop   test                1                        0
# 718  3118  fake    photoshop   test                1                        1
# 719  3119  fake    photoshop   test                1                        0
#
#      resnet_to_hsv
# ...

# %%
test_predictions = pd.concat([test_predictions, shallownet], axis=1)
test_predictions = pd.concat([test_predictions, xception], axis=1)
test_predictions = pd.concat([test_predictions, densenet[0:720]], axis=1)
test_predictions
# Out:
#        id label dataset_name folder  resnet_original  resnet_high_pass_filter  \
# 0       0  real         ffhq   test                0                        0
# 1       2  real         ffhq   test                1                        0
# 2       3  real         ffhq   test                0                        1
# 3       8  real         ffhq   test                1                        1
# 4      25  real         ffhq   test                0                        0
# ..    ...   ...          ...    ...              ...                      ...
# 715  3115  fake    photoshop   test                1                        1
# 716  3116  fake    photoshop   test                0                        0
# 717  3117  fake    photoshop   test                1                        0
# 718  3118  fake    photoshop   test                1                        1
# 719  3119  fake    photoshop   test                1                        0
#
# ...

# %%
test_predictions = test_predictions.drop(columns='folder')
test_predictions
# Out:
#        id label dataset_name  resnet_original  resnet_high_pass_filter  \
# 0       0  real         ffhq                0                        0
# 1       2  real         ffhq                1                        0
# 2       3  real         ffhq                0                        1
# 3       8  real         ffhq                1                        1
# 4      25  real         ffhq                0                        0
# ..    ...   ...          ...              ...                      ...
# 715  3115  fake    photoshop                1                        1
# 716  3116  fake    photoshop                0                        0
# 717  3117  fake    photoshop                1                        0
# 718  3118  fake    photoshop                1                        1
# 719  3119  fake    photoshop                1                        0
#
#      resnet_to_hsv  shallownet_original  high_pass_filter  shallownet_to_hsv  \
# ...

# %%
test_predictions = test_predictions.replace({'real': 0, 'fake': 1})
test_predictions
# Out:
#        id  label dataset_name  resnet_original  resnet_high_pass_filter  \
# 0       0      0         ffhq                0                        0
# 1       2      0         ffhq                1                        0
# 2       3      0         ffhq                0                        1
# 3       8      0         ffhq                1                        1
# 4      25      0         ffhq                0                        0
# ..    ...    ...          ...              ...                      ...
# 715  3115      1    photoshop                1                        1
# 716  3116      1    photoshop                0                        0
# 717  3117      1    photoshop                1                        0
# 718  3118      1    photoshop                1                        1
# 719  3119      1    photoshop                1                        0
#
#      resnet_to_hsv  shallownet_original  high_pass_filter  shallownet_to_hsv  \
# ...

# %%
test_predictions.to_csv('/content/drive/MyDrive/2023_Spring/Advanced_Topics_in_DS/Project/small_processed_data/test_predictions.csv', index=False)
